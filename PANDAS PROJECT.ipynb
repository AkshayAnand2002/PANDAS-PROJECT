# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_excel("C:/Amazon_Data.xlsx")

# %%
df1.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock  number_of_reviews  number_of_answered_questions  \
# 0                     5 new               15.0                           1.0
# 1                       NaN                2.0                           1.0
# ...

# %%
##date is of form: 7-2021 we want to split it into 2 parts 7 and 2021 for that we need to first convert it into string.
df1["date"].str.split("-")
# Out:
# 0        [7, 2021]
# 1       [11, 2019]
# 2       [11, 2021]
# 3        [9, 2019]
# 4        [8, 2021]
#            ...
# 9974     [7, 2020]
# 9975     [6, 2019]
# 9976     [3, 2021]
# 9977     [4, 2020]
# 9978     [4, 2019]
# Name: date, Length: 9979, dtype: object

# %%
df1["date"].str.split("-" , expand=True)
##the list seen above is converted to dataframe.
##epand=True makes sure that when splitted the list stays as dataframe.
# Out:
#        0     1
# 0      7  2021
# 1     11  2019
# 2     11  2021
# 3      9  2019
# 4      8  2021
# ...   ..   ...
# 9974   7  2020
# 9975   6  2019
# 9976   3  2021
# 9977   4  2020
# 9978   4  2019
#
# [9979 rows x 2 columns]

# %%
###assigning name to columns instead of 0 and 1 as column header names.
df1[["Month","Year"]]=df1["date"].str.split("-" , expand=True)

# %%
df1[["uniq_id","date","Month","Year"]]
# Out:
#                                uniq_id     date Month  Year
# 0     eac7efa5dbd3d667f26eb3d3ab504464   7-2021     7  2021
# 1     b17540ef7e86e461d37f3ae58b7b72ac  11-2019    11  2019
# 2     348f344247b0c1a935b1223072ef9d8a  11-2021    11  2021
# 3     e12b92dbb8eaee78b22965d2a9bbbd9f   9-2019     9  2019
# 4     e33a9adeed5f36840ccc227db4682a36   8-2021     8  2021
# ...                                ...      ...   ...   ...
# 9974  44d6967f083825a5de36ad4865a65bcd   7-2020     7  2020
# 9975  08f0747b6fc6687215ffb994c3a6fb32   6-2019     6  2019
# 9976  bf6cc073f8f24e6e338190fa16f6ee9d   3-2021     3  2021
# 9977  cd783d0b8b44e631b9788b203eaaefae   4-2020     4  2020
# 9978  94d18e86e504bee1e392df7e5738b18a   4-2019     4  2019
#
# [9979 rows x 4 columns]

# %%
df1
# Out:
#                                uniq_id  \
# 0     eac7efa5dbd3d667f26eb3d3ab504464
# 1     b17540ef7e86e461d37f3ae58b7b72ac
# 2     348f344247b0c1a935b1223072ef9d8a
# 3     e12b92dbb8eaee78b22965d2a9bbbd9f
# 4     e33a9adeed5f36840ccc227db4682a36
# ...                                ...
# 9974  44d6967f083825a5de36ad4865a65bcd
# 9975  08f0747b6fc6687215ffb994c3a6fb32
# 9976  bf6cc073f8f24e6e338190fa16f6ee9d
# 9977  cd783d0b8b44e631b9788b203eaaefae
# 9978  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9974  Batman 1966 TV Series Action Figures - The Rid...
# ...

# %%
df1["number_of_reviews"]=df1["number_of_reviews"].fillna(0)
df1["number_of_answered_questions"]=df1["number_of_answered_questions"].fillna(0)
###fills all blanks with 0 value.

# %%
df1
# Out:
#                                uniq_id  \
# 0     eac7efa5dbd3d667f26eb3d3ab504464
# 1     b17540ef7e86e461d37f3ae58b7b72ac
# 2     348f344247b0c1a935b1223072ef9d8a
# 3     e12b92dbb8eaee78b22965d2a9bbbd9f
# 4     e33a9adeed5f36840ccc227db4682a36
# ...                                ...
# 9974  44d6967f083825a5de36ad4865a65bcd
# 9975  08f0747b6fc6687215ffb994c3a6fb32
# 9976  bf6cc073f8f24e6e338190fa16f6ee9d
# 9977  cd783d0b8b44e631b9788b203eaaefae
# 9978  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9974  Batman 1966 TV Series Action Figures - The Rid...
# ...

# %%
df1["price"]=df1["price"].fillna("€0")

# %%
df1["currency"]=df1["price"].str[0:1]###to take only euro or pound symbol from price column values.

# %%
df1.head()
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
#
#                                         product_name manufacturer   price  \
# 0                              Hornby 2014 Catalogue       Hornby   £3.42
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys  £16.99
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf   £9.99
# 3     HORNBY Coach R4410A BR Hawksworth Corridor 3rd       Hornby  £39.99
# 4  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...       Hornby  £32.19
#
#   number_available_in_stock  number_of_reviews  number_of_answered_questions  \
# 0                     5 new               15.0                           1.0
# 1                       NaN                2.0                           1.0
# ...

# %%
df1["price"]=df1["price"].str[1:]##to take nos. as string after pound or euro symbol.

# %%
df1
# Out:
#                                uniq_id  \
# 0     eac7efa5dbd3d667f26eb3d3ab504464
# 1     b17540ef7e86e461d37f3ae58b7b72ac
# 2     348f344247b0c1a935b1223072ef9d8a
# 3     e12b92dbb8eaee78b22965d2a9bbbd9f
# 4     e33a9adeed5f36840ccc227db4682a36
# ...                                ...
# 9974  44d6967f083825a5de36ad4865a65bcd
# 9975  08f0747b6fc6687215ffb994c3a6fb32
# 9976  bf6cc073f8f24e6e338190fa16f6ee9d
# 9977  cd783d0b8b44e631b9788b203eaaefae
# 9978  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3        HORNBY Coach R4410A BR Hawksworth Corridor 3rd
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# ...                                                 ...
# 9974  Batman 1966 TV Series Action Figures - The Rid...
# ...

# %%
##seeing the price column valuess as float values.
df1["price"].astype(float)###here we converted string to float.
# Out:
# 0        3.42
# 1       16.99
# 2        9.99
# 3       39.99
# 4       32.19
#         ...
# 9974    22.95
# 9975    39.99
# 9976    43.99
# 9977    49.81
# 9978    21.20
# Name: price, Length: 9979, dtype: float64

# %%
###to get nearest integer value we use round function.
round(df1["price"].astype(float))##we rounded float to integer.
# Out:
# 0        3.0
# 1       17.0
# 2       10.0
# 3       40.0
# 4       32.0
#         ...
# 9974    23.0
# 9975    40.0
# 9976    44.0
# 9977    50.0
# 9978    21.0
# Name: price, Length: 9979, dtype: float64

# %%
###we need to remove decimal to convert it into integer.no decimal point in column values.
round(df1["price"].astype(float)).astype(int)
# Out:
# 0        3
# 1       17
# 2       10
# 3       40
# 4       32
#         ..
# 9974    23
# 9975    40
# 9976    44
# 9977    50
# 9978    21
# Name: price, Length: 9979, dtype: int32

# %%
###now saving above result to price column.
df1["price"] = round(df1["price"].astype(float)).astype(int)

# %%
df1.head(3)
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
#
#                                         product_name manufacturer  price  \
# 0                              Hornby 2014 Catalogue       Hornby      3
# 1  FunkyBuys® Large Christmas Holiday Express Fes...    FunkyBuys     17
# 2  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...          ccf     10
#
#   number_available_in_stock  number_of_reviews  number_of_answered_questions  \
# 0                     5 new               15.0                           1.0
# 1                       NaN                2.0                           1.0
# 2                     2 new               17.0                           2.0
#
#   average_review_rating                   amazon_category_and_sub_category  \
# 0    4.9 out of 5 stars  Hobbies > Model Trains & Railway Sets > Rail V...
# ...

# %%
len(df1.columns)###counting no. of columns.
# Out:
# 20

# %%
del df1["customer_questions_and_answers"]

# %%
len(df1.columns)###counting no. of columns.
# Out:
# 19

# %%
df1["Engaging Customers"] = np.where(df1["customers_who_bought_this_item_also_bought"].isnull() & df1["items_customers_buy_after_viewing_this_item"].isnull() , False , True)
##checking conditions and putting in a column.

# %%
df1[["uniq_id","customers_who_bought_this_item_also_bought","items_customers_buy_after_viewing_this_item","Engaging Customers"]].head(10)
##getting required columns.
##if a person is buying more than 1 item or more items than original item then he/she is a true engaging customer.
# Out:
#                             uniq_id  \
# 0  eac7efa5dbd3d667f26eb3d3ab504464
# 1  b17540ef7e86e461d37f3ae58b7b72ac
# 2  348f344247b0c1a935b1223072ef9d8a
# 3  e12b92dbb8eaee78b22965d2a9bbbd9f
# 4  e33a9adeed5f36840ccc227db4682a36
# 5  cb34f0a84102c1ebc3ef6892d7444d36
# 6  f74b562470571dfb689324adf236f82c
# 7  87bbb472ef9d90dcef140a551665c929
# 8  7e2aa2b4596a39ba852449718413d7cc
# 9  5afbaf65680c9f378af5b3a3ae22427e
#
#           customers_who_bought_this_item_also_bought  \
# 0  http://www.amazon.co.uk/Hornby-R8150-Catalogue...
# 1  http://www.amazon.co.uk/Christmas-Holiday-Expr...
# 2  http://www.amazon.co.uk/Classic-Train-Lights-B...
# 3                                                NaN
# 4  http://www.amazon.co.uk/Hornby-R6367-RailRoad-...
# 5  http://www.amazon.co.uk/Single-Head-Garden-Lig...
# 6  http://www.amazon.co.uk/Hornby-R4388-RailRoad-...
# 7  http://www.amazon.co.uk/Hornby-R8221-Gauge-Tra...
# 8  http://www.amazon.co.uk/Hornby-Western-Master-...
# ...

# %%
df1.loc[df1["Engaging Customers"] == True]
# Out:
#                                uniq_id  \
# 0     eac7efa5dbd3d667f26eb3d3ab504464
# 1     b17540ef7e86e461d37f3ae58b7b72ac
# 2     348f344247b0c1a935b1223072ef9d8a
# 4     e33a9adeed5f36840ccc227db4682a36
# 5     cb34f0a84102c1ebc3ef6892d7444d36
# ...                                ...
# 9973  791719b23e393dc4a3384d4d7777c089
# 9974  44d6967f083825a5de36ad4865a65bcd
# 9975  08f0747b6fc6687215ffb994c3a6fb32
# 9976  bf6cc073f8f24e6e338190fa16f6ee9d
# 9978  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# 5     20pcs Model Garden Light Double Heads Lamppost...
# ...                                                 ...
# 9973  Factory Entertainment Green Hornet Movie: Kato...
# ...

# %%
df1 = df1.loc[df1["Engaging Customers"] == True]

# %%
df1
# Out:
#                                uniq_id  \
# 0     eac7efa5dbd3d667f26eb3d3ab504464
# 1     b17540ef7e86e461d37f3ae58b7b72ac
# 2     348f344247b0c1a935b1223072ef9d8a
# 4     e33a9adeed5f36840ccc227db4682a36
# 5     cb34f0a84102c1ebc3ef6892d7444d36
# ...                                ...
# 9973  791719b23e393dc4a3384d4d7777c089
# 9974  44d6967f083825a5de36ad4865a65bcd
# 9975  08f0747b6fc6687215ffb994c3a6fb32
# 9976  bf6cc073f8f24e6e338190fa16f6ee9d
# 9978  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# 5     20pcs Model Garden Light Double Heads Lamppost...
# ...                                                 ...
# 9973  Factory Entertainment Green Hornet Movie: Kato...
# ...

# %%
###loc is label based location where label is that a particular condition written above is true.

# %%
len(df1)###getting no. of rows . they have reduced as we got rid of non-engaging customers.
# Out:
# 9025

# %%
mylist = df1.columns

# %%
print(mylist)
# Out:
# Index(['uniq_id', 'product_name', 'manufacturer', 'price',
#        'number_available_in_stock', 'number_of_reviews',
#        'number_of_answered_questions', 'average_review_rating',
#        'amazon_category_and_sub_category',
#        'customers_who_bought_this_item_also_bought', 'description',
#        'product_information', 'product_description',
#        'items_customers_buy_after_viewing_this_item', 'customer_reviews',
#        'date', 'Month', 'Year', 'currency', 'Engaging Customers'],
#       dtype='object')

# %%
##we don't need all columns so we make a list agian.

# %%
mylist= ['uniq_id', 'product_name', 'manufacturer', 'price',
       'number_available_in_stock', 'number_of_reviews',
       'number_of_answered_questions', 'average_review_rating',
       'amazon_category_and_sub_category',
       'product_information', 'product_description',
       'customer_reviews',
       'date', 'Month', 'Year', 'currency', 'Engaging Customers']
###'items_customers_buy_after_viewing_this_item','customers_who_bought_this_item_also_bought' are removed from above.

# %%
print(mylist)
# Out:
# ['uniq_id', 'product_name', 'manufacturer', 'price', 'number_available_in_stock', 'number_of_reviews', 'number_of_answered_questions', 'average_review_rating', 'amazon_category_and_sub_category', 'product_information', 'product_description', 'customer_reviews', 'date', 'Month', 'Year', 'currency', 'Engaging Customers']

# %%
###2 columns which we have removed we want to convert them into single column or we want to unpivot them.
df1.melt(id_vars= mylist , var_name="buying_customers" , value_name="buying_customer_links")
# Out:
#                                 uniq_id  \
# 0      eac7efa5dbd3d667f26eb3d3ab504464
# 1      b17540ef7e86e461d37f3ae58b7b72ac
# 2      348f344247b0c1a935b1223072ef9d8a
# 3      e33a9adeed5f36840ccc227db4682a36
# 4      cb34f0a84102c1ebc3ef6892d7444d36
# ...                                 ...
# 27070  791719b23e393dc4a3384d4d7777c089
# 27071  44d6967f083825a5de36ad4865a65bcd
# 27072  08f0747b6fc6687215ffb994c3a6fb32
# 27073  bf6cc073f8f24e6e338190fa16f6ee9d
# 27074  94d18e86e504bee1e392df7e5738b18a
#
#                                             product_name  \
# 0                                  Hornby 2014 Catalogue
# 1      FunkyBuys® Large Christmas Holiday Express Fes...
# 2      CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3      Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# 4      20pcs Model Garden Light Double Heads Lamppost...
# ...                                                  ...
# 27070  Factory Entertainment Green Hornet Movie: Kato...
# ...

# %%
##the 2 removed columns are present in a single column called buying_customers.

# %%
##changing no. of items available in stocks.
##in number_available_in_stock we have to remove NaN and new.
df1["number_available_in_stock"] = df1["number_available_in_stock"].str.replace("new","")

# %%
df1["number_available_in_stock"]
# Out:
# 0        5
# 1       NaN
# 2        2
# 4       NaN
# 5       NaN
#        ...
# 9973    NaN
# 9974     5
# 9975    NaN
# 9976     3
# 9978    31
# Name: number_available_in_stock, Length: 9025, dtype: object

# %%
##removed 'new' from place in above step.

# %%
df1["number_available_in_stock"]=df1["number_available_in_stock"].fillna(0)

# %%
df1["number_available_in_stock"]
# Out:
# 0        5
# 1         0
# 2        2
# 4         0
# 5         0
#        ...
# 9973      0
# 9974     5
# 9975      0
# 9976     3
# 9978    31
# Name: number_available_in_stock, Length: 9025, dtype: object

# %%
##Because of space between no and new we see numbers as in above.

# %%
df1["number_available_in_stock"].str.strip()
# Out:
# 0         5
# 1       NaN
# 2         2
# 4       NaN
# 5       NaN
#        ...
# 9973    NaN
# 9974      5
# 9975    NaN
# 9976      3
# 9978     31
# Name: number_available_in_stock, Length: 9025, dtype: object

# %%
##NaN again came.

# %%
##we agin repeat above steps to get required form of output.
df1["number_available_in_stock"]=df1["number_available_in_stock"].str.strip()
df1["number_available_in_stock"]=df1["number_available_in_stock"].fillna(0)
df1["number_available_in_stock"]
# Out:
# 0        5
# 1        0
# 2        2
# 4        0
# 5        0
#         ..
# 9973     0
# 9974     5
# 9975     0
# 9976     3
# 9978    31
# Name: number_available_in_stock, Length: 9025, dtype: object

# %%
##WE GOT CORRECT OUTPUT.

# %%
##dropping or removing some columns.
df1.drop(["product_information","product_description"] , inplace=True , axis = 1)

# %%
df1
# Out:
#                                uniq_id  \
# 0     eac7efa5dbd3d667f26eb3d3ab504464
# 1     b17540ef7e86e461d37f3ae58b7b72ac
# 2     348f344247b0c1a935b1223072ef9d8a
# 4     e33a9adeed5f36840ccc227db4682a36
# 5     cb34f0a84102c1ebc3ef6892d7444d36
# ...                                ...
# 9973  791719b23e393dc4a3384d4d7777c089
# 9974  44d6967f083825a5de36ad4865a65bcd
# 9975  08f0747b6fc6687215ffb994c3a6fb32
# 9976  bf6cc073f8f24e6e338190fa16f6ee9d
# 9978  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# 0                                 Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# 5     20pcs Model Garden Light Double Heads Lamppost...
# ...                                                 ...
# 9973  Factory Entertainment Green Hornet Movie: Kato...
# ...

# %%
df1= df1.rename({"uniq_id":"unique_id"} , axis =1 )##axis=1 means columns.

# %%
df1.columns
# Out:
# Index(['unique_id', 'product_name', 'manufacturer', 'price',
#        'number_available_in_stock', 'number_of_reviews',
#        'number_of_answered_questions', 'average_review_rating',
#        'amazon_category_and_sub_category',
#        'customers_who_bought_this_item_also_bought', 'description',
#        'items_customers_buy_after_viewing_this_item', 'customer_reviews',
#        'date', 'Month', 'Year', 'currency', 'Engaging Customers'],
#       dtype='object')

# %%
##axis = 0 means rows.
df1= df1.rename({0:"ZERO"} , axis =0 )##MAKING 0 INDEX IN ROW NAMED AS ZERO.

# %%
df1
# Out:
#                              unique_id  \
# ZERO  eac7efa5dbd3d667f26eb3d3ab504464
# 1     b17540ef7e86e461d37f3ae58b7b72ac
# 2     348f344247b0c1a935b1223072ef9d8a
# 4     e33a9adeed5f36840ccc227db4682a36
# 5     cb34f0a84102c1ebc3ef6892d7444d36
# ...                                ...
# 9973  791719b23e393dc4a3384d4d7777c089
# 9974  44d6967f083825a5de36ad4865a65bcd
# 9975  08f0747b6fc6687215ffb994c3a6fb32
# 9976  bf6cc073f8f24e6e338190fa16f6ee9d
# 9978  94d18e86e504bee1e392df7e5738b18a
#
#                                            product_name  \
# ZERO                              Hornby 2014 Catalogue
# 1     FunkyBuys® Large Christmas Holiday Express Fes...
# 2     CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 4     Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# 5     20pcs Model Garden Light Double Heads Lamppost...
# ...                                                 ...
# 9973  Factory Entertainment Green Hornet Movie: Kato...
# ...

# %%
df1.to_excel(r"C:\Users\aksha\OneDrive\Desktop\Amazon_Data_To_Excel_Using_Pandas_Python.xlsx",index=False,sheet_name="Project By Pandas")
##removes 1st column of index and gives sheet name.
